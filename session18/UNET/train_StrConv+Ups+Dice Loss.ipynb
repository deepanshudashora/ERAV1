# %% [markdown]
# # Environment Setup

# %%
# !git clone https://github.com/anantgupta129/TorcHood.git
# %cd TorcHood

# %%
# from IPython.display import clear_output

# !python setup.py sdist
# !pip install .

# clear_output()
# %cd ..

# %% [markdown]
# # Importing Libaries

# %%
import warnings
warnings.filterwarnings("ignore")

import os 
import torch

import lightning.pytorch as pl
from torchood.data.oxfordpets_module import OxfordIiitPetsDataModule
from torchood.models.unet_module import UNetLitModule

# %%
config = {
    "project_name" : "Unet-Oxford-Iiit-Pets", # Wandb project name
    "run_name" : "StrConv+ups+dice", # wandb run name
    "num_epochs" : 50,
    "lr": 1e-3
}

# %%
datamodule = OxfordIiitPetsDataModule(
    image_dir="datasets/oxford_iiit_pets/images", 
    mask_dir="datasets/oxford_iiit_pets/annotations/trimaps",
    batch_size=16,
    num_workers=8,
    pin_memory=True
)

# %%
model = UNetLitModule(learning_rate=config["lr"], out_channels=3, strided_conv=True, upsample_mode="upsample")

# %%
from lightning.pytorch.callbacks import LearningRateMonitor
from lightning.pytorch.loggers import WandbLogger


callbacks = [LearningRateMonitor(logging_interval="step")]
logger = WandbLogger(project=config["project_name"], name=config["run_name"])
trainer = pl.Trainer(
    callbacks=callbacks,
    logger=logger,
    max_epochs=config["num_epochs"],
    accelerator = "gpu",
)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: anantgupta129. Use `wandb login --relogin` to force relogin
# ...
# wandb version 0.15.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>./wandb/run-20230922_112551-2tyy1q8m</code>
# Syncing run <strong><a href='https://wandb.ai/anantgupta129/Unet-Oxford-Iiit-Pets/runs/2tyy1q8m' target="_blank">StrConv+ups+dice</a></strong> to <a href='https://wandb.ai/anantgupta129/Unet-Oxford-Iiit-Pets' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anantgupta129/Unet-Oxford-Iiit-Pets' target="_blank">https://wandb.ai/anantgupta129/Unet-Oxford-Iiit-Pets</a>
# ...

# %%
import matplotlib.pyplot as plt

model.to("cuda")
for i, (x, y) in enumerate(datamodule.val_dataloader()):
    # taking only first image from batch
    x = x[0].unsqueeze(0)
    y = y[0]

    pred = model(x.to("cuda"))
    pred = pred.argmax(dim=1).squeeze().cpu().numpy()

    plt.subplot(1, 3, 1)
    plt.imshow(x[0].permute(1, 2, 0))
    plt.axis("off")
    
    plt.subplot(1, 3, 2)
    plt.imshow(y)
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred)
    plt.axis("off")

    plt.show()
    if i==10:
        break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
